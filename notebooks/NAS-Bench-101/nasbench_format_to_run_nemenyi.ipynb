# %%
import argparse

import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
subset = 108
n = 172
selected_models = ['LinearRegression', 'RandomForestRegressor', 'BayesianRidge', 'DummyRegressor']

# %%
df_results = pd.read_csv(str("/home/gean/Code/nns_performance_prediction/results/fast/test12/N" + 
                             str(n) + "_nasbench_metrics_formatted.csv"))
df_results = df_results.loc[df_results['Model'].isin(selected_models)]

df_results = df_results.astype({'Seed': np.int16, 'Subset': np.int16, 'MAE': np.float32, 'MSE': np.float32, 'R2': np.float32})
df_results.head(12)
# Out:
#     Seed  Subset                  Model       MAE       MSE        R2
# 0      0       4       LinearRegression  0.114755  0.020631 -0.010661
# 3      0       4          BayesianRidge  0.114546  0.020379  0.001656
# 8      0       4  RandomForestRegressor  0.115189  0.020908 -0.024240
# 11     0       4         DummyRegressor  0.119830  0.021108 -0.034054
# 12     0      12       LinearRegression  0.163408  0.037073  0.043390
# 15     0      12          BayesianRidge  0.163551  0.036600  0.055580
# 20     0      12  RandomForestRegressor  0.162367  0.036204  0.065813
# 23     0      12         DummyRegressor  0.172058  0.039421 -0.017211
# 24     0      36       LinearRegression  0.055031  0.007533  0.113143
# 27     0      36          BayesianRidge  0.056005  0.007654  0.098931
# 32     0      36  RandomForestRegressor  0.055956  0.007655  0.098813
# 35     0      36         DummyRegressor  0.059608  0.008571 -0.008992

# %%
df_results_gcn = pd.read_csv(str("/home/gean/Downloads/compilado_test/runs_p_test/runs_" + str(subset) + ".csv"))
df_results_gcn = df_results_gcn.drop(['id_run', 'loss', 'time'], axis=1) 
df_results_gcn = df_results_gcn.loc[(df_results_gcn['dataset'] == subset) & (df_results_gcn['train_size'] == n)]
df_results_gcn = df_results_gcn.rename(columns={"dataset": "Subset", "seed": "Seed", "mae": "MAE", "mse": "MSE", "r2": "R2"})
df_results_gcn = df_results_gcn.drop(['train_size'], axis=1)
df_results_gcn['Model'] = 'Graph Convolutional Network'
df_results_gcn
# Out:
#     Subset   Seed       MSE       MAE        R2                        Model
# 3      108      0  0.004686  0.020649  0.073955  Graph Convolutional Network
# 7      108      1  0.004403  0.022709  0.076716  Graph Convolutional Network
# 11     108     10  0.004651  0.020515  0.072613  Graph Convolutional Network
# 15     108     42  0.004505  0.020573  0.076840  Graph Convolutional Network
# 19     108    100  0.004558  0.022712  0.072137  Graph Convolutional Network
# 23     108    123  0.004594  0.021148  0.075754  Graph Convolutional Network
# 27     108    666  0.004639  0.025696  0.053953  Graph Convolutional Network
# 30     108   1000  0.004841  0.030320  0.021601  Graph Convolutional Network
# 34     108   1234  0.004603  0.019918  0.068330  Graph Convolutional Network
# 38     108  12345  0.004512  0.021255  0.079664  Graph Convolutional Network

# %%
df_results_subset = df_results[df_results['Subset'] == subset]
df_results_subset = df_results_subset.append(df_results_gcn)
df_results_subset = df_results_subset.reset_index()
df_results_subset
# Out:
#     index   Seed  Subset                        Model       MAE       MSE  \
# 0      36      0     108             LinearRegression  0.023835  0.003108
# 1      39      0     108                BayesianRidge  0.024305  0.003180
# 2      44      0     108        RandomForestRegressor  0.018282  0.003090
# 3      47      0     108               DummyRegressor  0.028603  0.003514
# 4      84      1     108             LinearRegression  0.022131  0.003111
# 5      87      1     108                BayesianRidge  0.021202  0.003082
# 6      92      1     108        RandomForestRegressor  0.018144  0.003101
# 7      95      1     108               DummyRegressor  0.023036  0.003506
# 8     132     10     108             LinearRegression  0.019767  0.003129
# 9     135     10     108                BayesianRidge  0.019819  0.003142
# 10    140     10     108        RandomForestRegressor  0.018114  0.003054
# 11    143     10     108               DummyRegressor  0.023007  0.003516
# 12    180     42     108             LinearRegression  0.022832  0.003068
# 13    183     42     108                BayesianRidge  0.022098  0.003057
# 14    188     42     108        RandomForestRegressor  0.018257  0.003122
# 15    191     42     108               DummyRegressor  0.023016  0.003511
# 16    228    100     108             LinearRegression  0.023364  0.003156
# 17    231    100     108                BayesianRidge  0.022822  0.003125
# 18    236    100     108        RandomForestRegressor  0.018848  0.003081
# 19    239    100     108               DummyRegressor  0.027802  0.003491
# 20    276    123     108             LinearRegression  0.020999  0.003156
# 21    279    123     108                BayesianRidge  0.020448  0.003134
# 22    284    123     108        RandomForestRegressor  0.018405  0.003181
# 23    287    123     108               DummyRegressor  0.023637  0.003687
# 24    324    666     108             LinearRegression  0.021014  0.003098
# 25    327    666     108                BayesianRidge  0.020866  0.003109
# 26    332    666     108        RandomForestRegressor  0.018182  0.003097
# 27    335    666     108               DummyRegressor  0.023219  0.003480
# 28    372   1000     108             LinearRegression  0.024963  0.003287
# 29    375   1000     108                BayesianRidge  0.024052  0.003232
# 30    380   1000     108        RandomForestRegressor  0.018638  0.003178
# 31    383   1000     108               DummyRegressor  0.022992  0.003555
# 32    420   1234     108             LinearRegression  0.024252  0.003343
# 33    423   1234     108                BayesianRidge  0.023317  0.003269
# 34    428   1234     108        RandomForestRegressor  0.023728  0.003556
# 35    431   1234     108               DummyRegressor  0.024610  0.003439
# 36    468  12345     108             LinearRegression  0.021922  0.003161
# 37    471  12345     108                BayesianRidge  0.020937  0.003115
# 38    476  12345     108        RandomForestRegressor  0.018369  0.003076
# 39    479  12345     108               DummyRegressor  0.023077  0.003497
# 40      3      0     108  Graph Convolutional Network  0.020649  0.004686
# 41      7      1     108  Graph Convolutional Network  0.022709  0.004403
# 42     11     10     108  Graph Convolutional Network  0.020515  0.004651
# 43     15     42     108  Graph Convolutional Network  0.020573  0.004505
# 44     19    100     108  Graph Convolutional Network  0.022712  0.004558
# 45     23    123     108  Graph Convolutional Network  0.021148  0.004594
# 46     27    666     108  Graph Convolutional Network  0.025696  0.004639
# 47     30   1000     108  Graph Convolutional Network  0.030320  0.004841
# 48     34   1234     108  Graph Convolutional Network  0.019918  0.004603
# 49     38  12345     108  Graph Convolutional Network  0.021255  0.004512
#
#           R2
# 0   0.095885
# 1   0.075128
# 2   0.101176
# 3  -0.022175
# 4   0.095645
# 5   0.104016
# 6   0.098367
# 7  -0.019182
# 8   0.090575
# 9   0.086620
# 10  0.112215
# 11 -0.021874
# 12  0.108099
# 13  0.111128
# 14  0.092367
# 15 -0.020706
# 16  0.082381
# 17  0.091385
# 18  0.104175
# 19 -0.015170
# 20  0.082517
# 21  0.088810
# 22  0.075242
# 23 -0.071697
# 24  0.099624
# 25  0.096433
# 26  0.099683
# 27 -0.011552
# 28  0.044279
# 29  0.060217
# 30  0.075819
# 31 -0.033770
# 32  0.027994
# 33  0.049551
# 34 -0.033898
# 35 -0.000026
# 36  0.081118
# 37  0.094434
# 38  0.105732
# 39 -0.016744
# 40  0.073955
# 41  0.076716
# 42  0.072613
# 43  0.076840
# 44  0.072137
# 45  0.075754
# 46  0.053953
# 47  0.021601
# 48  0.068330
# 49  0.079664

# %% [markdown]
# ## Nemenyi test

# %% [markdown]
# ##### MAE

# %%
mae_nemenyi = {}

for unique in df_results_subset['Model'].unique():
    mae_nemenyi[unique] = list(df_results_subset[df_results_subset['Model'] == unique]['MAE'])

# %%
df_mae_nemenyi = pd.DataFrame.from_dict(mae_nemenyi)
df_mae_nemenyi = df_mae_nemenyi.rename(columns={"LinearRegression": "Linear Regression", 
                                                "RandomForestRegressor": "Random Forest",
                                                "BayesianRidge": "Bayesian Ridge",
                                                "DummyRegressor": "Dummy"})
df_mae_nemenyi.to_csv(str("/home/gean/Code/nns_performance_prediction/results/fast/test12/n" + 
                      str(n) + "_subset" + str(subset) + "_mae_nemenyi.csv"), 
                  index=False, float_format='%.6f')
df_mae_nemenyi
# Out:
#    Linear Regression  Bayesian Ridge  Random Forest     Dummy  \
# 0           0.023835        0.024305       0.018282  0.028603
# 1           0.022131        0.021202       0.018144  0.023036
# 2           0.019767        0.019819       0.018114  0.023007
# 3           0.022832        0.022098       0.018257  0.023016
# 4           0.023364        0.022822       0.018848  0.027802
# 5           0.020999        0.020448       0.018405  0.023637
# 6           0.021014        0.020866       0.018182  0.023219
# 7           0.024963        0.024052       0.018638  0.022992
# 8           0.024252        0.023317       0.023728  0.024610
# 9           0.021922        0.020937       0.018369  0.023077
#
#    Graph Convolutional Network
# 0                     0.020649
# 1                     0.022709
# 2                     0.020515
# 3                     0.020573
# 4                     0.022712
# 5                     0.021148
# 6                     0.025696
# 7                     0.030320
# 8                     0.019918
# 9                     0.021255

# %% [markdown]
# ##### MSE

# %%
mse_nemenyi = {}

for unique in df_results_subset['Model'].unique():
    mse_nemenyi[unique] = list(df_results_subset[df_results_subset['Model'] == unique]['MSE'])

# %%
df_mse_nemenyi = pd.DataFrame.from_dict(mse_nemenyi)
df_mse_nemenyi = df_mse_nemenyi.rename(columns={"LinearRegression": "Linear Regression", 
                                                "RandomForestRegressor": "Random Forest", 
                                                "BayesianRidge": "Bayesian Ridge",
                                                "DummyRegressor": "Dummy"})
df_mse_nemenyi.to_csv(str("/home/gean/Code/nns_performance_prediction/results/fast/test12/n" + 
                      str(n) + "_subset" + str(subset) + "_mse_nemenyi.csv"), 
                  index=False, float_format='%.6f')

df_mse_nemenyi.head(12)
# Out:
#    Linear Regression  Bayesian Ridge  Random Forest     Dummy  \
# 0           0.003108        0.003180       0.003090  0.003514
# 1           0.003111        0.003082       0.003101  0.003506
# 2           0.003129        0.003142       0.003054  0.003516
# 3           0.003068        0.003057       0.003122  0.003511
# 4           0.003156        0.003125       0.003081  0.003491
# 5           0.003156        0.003134       0.003181  0.003687
# 6           0.003098        0.003109       0.003097  0.003480
# 7           0.003287        0.003232       0.003178  0.003555
# 8           0.003343        0.003269       0.003556  0.003439
# 9           0.003161        0.003115       0.003076  0.003497
#
#    Graph Convolutional Network
# 0                     0.004686
# 1                     0.004403
# 2                     0.004651
# 3                     0.004505
# 4                     0.004558
# 5                     0.004594
# 6                     0.004639
# 7                     0.004841
# 8                     0.004603
# 9                     0.004512
