# %%
import argparse

import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
parser = argparse.ArgumentParser()
 
parser.add_argument('--data_path', type=str, default='/home/gean/Code/nns_performance_prediction/results/', help='location of the dataset')    
parser.add_argument('--results_path', type=str, default='/home/gean/Code/nns_performance_prediction/results/', help='location of the results directory')    

parser.add_argument('--data_subset', type=int, default=[4, 12], help='one of the subsets from nasbench101 with 4, 12, 36, or 108 epochs')
parser.add_argument('--seed', type=int, default=[0, 1], nargs='+', help='seeds used for all the random procedures') 
parser.add_argument('--train_size', type=int, default=[43], help='[Int, Int...] representing the total number of train samples')
parser.add_argument('--estimators', type=str, default=['LinearRegression', 'SGDRegressor', 'Lasso', 'BayesianRidge', 'KNeighborsRegressor', 'DecisionTreeRegressor',
                                                       'SVR', 'MLPRegressor', 'RandomForestRegressor', 'AdaBoostRegressor', 'GradientBoostingRegressor', 
                                                       'DummyRegressor'], nargs='+', help='list of sklearn estimators to be used for training') 

args, unknown = parser.parse_known_args()

# %%
def set_default_seed(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)

# %%
def save_results(performance_dict, file_name): 
    df_results = pd.DataFrame.from_dict(performance_dict)
    df_results.to_csv(str(args.results_path + file_name + '.csv'),
                      index=False, float_format='%.6f')

# %%
def extract_statistics():    
    for n in args.train_size:
        mae_values = {'LinearRegression_MAE': [], 'SGDRegressor_MAE': [], 'Lasso_MAE': [], 'BayesianRidge_MAE': [], 'KNeighborsRegressor_MAE': [], 
                      'DecisionTreeRegressor_MAE': [], 'SVR_MAE': [], 'MLPRegressor_MAE': [], 'RandomForestRegressor_MAE': [], 'AdaBoostRegressor_MAE': [], 
                      'GradientBoostingRegressor_MAE': [], 'DummyRegressor_MAE': []}
        
        mse_values = {'LinearRegression_MSE': [], 'SGDRegressor_MSE': [], 'Lasso_MSE': [], 'BayesianRidge_MSE': [], 'KNeighborsRegressor_MSE': [], 
                      'DecisionTreeRegressor_MSE': [], 'SVR_MSE': [], 'MLPRegressor_MSE': [], 'RandomForestRegressor_MSE': [], 'AdaBoostRegressor_MSE': [], 
                      'GradientBoostingRegressor_MSE': [], 'DummyRegressor_MSE': []}
            
        r2_values = {'LinearRegression_R2': [], 'SGDRegressor_R2': [], 'Lasso_R2': [], 'BayesianRidge_R2': [], 'KNeighborsRegressor_R2': [], 
                      'DecisionTreeRegressor_R2': [], 'SVR_R2': [], 'MLPRegressor_R2': [], 'RandomForestRegressor_R2': [], 'AdaBoostRegressor_R2': [], 
                      'GradientBoostingRegressor_R2': [], 'DummyRegressor_R2': []}
    
        df_whole = pd.read_csv(str(args.data_path + 'N' + str(n) +'_nasbench_predictions.csv'))
        
        for seed in args.seed:
            set_default_seed(seed)
        
            for subset in args.data_subset:
                y_true_column = str('Seed' + str(seed) + '_Subset' + str(subset) + '_N' + str(n) + '_Ytrue')  
                y_true = df_whole[y_true_column]

                print("\nN{}, Seed{}, Subset{}: \n".format(n, seed, subset))
                
                for reg in args.estimators:  
                    y_pred_column = str('Seed' + str(seed) + '_Subset' + str(subset) + '_N' + str(n) + '_' + str(reg) + '_Ypred')  
                    y_pred = df_whole[y_pred_column]
                    
                    mae = mean_absolute_error(y_true, y_pred)
                    mae_values[str(reg + '_MAE')].append(mae)
                    
                    mse = mean_squared_error(y_true, y_pred)
                    mse_values[str(reg + '_MSE')].append(mse)
                    
                    r2 = r2_score(y_true, y_pred)
                    r2_values[str(reg + '_R2')].append(r2)
                    
                    print(reg)
                    print("y_true column: {}".format(y_true_column))
                    print("y_pred column: {} \n".format(y_pred_column))
                        
        performance_metrics = {**mae_values, **mse_values, **r2_values}
        
        print("performance_metrics dict: \n{}".format(performance_metrics))
        
        #one file per n
        save_results(performance_metrics, str("N" + str(n) + "_nasbench_metrics"))

# %%
if __name__ == '__main__':
    
    print("data_path: ", args.data_path)
    print("results_path: ", args.results_path)
    print("data_subset: ", args.data_subset)
    print("seed: ", args.seed)
    print("train_size: ", args.train_size)                
    print("estimators: ", args.estimators)
    
    extract_statistics()
# Out:
# data_path:  /home/gean/Code/nns_performance_prediction/results/
# results_path:  /home/gean/Code/nns_performance_prediction/results/
# data_subset:  [4, 12]
# seed:  [0, 1]
# train_size:  [43]
# estimators:  ['LinearRegression', 'SGDRegressor', 'Lasso', 'BayesianRidge', 'KNeighborsRegressor', 'DecisionTreeRegressor', 'SVR', 'MLPRegressor', 'RandomForestRegressor', 'AdaBoostRegressor', 'GradientBoostingRegressor', 'DummyRegressor']
#
# N43, Seed0, Subset4:
#
# LinearRegression
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_LinearRegression_Ypred
#
# SGDRegressor
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_SGDRegressor_Ypred
#
# Lasso
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_Lasso_Ypred
#
# BayesianRidge
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_BayesianRidge_Ypred
#
# KNeighborsRegressor
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_KNeighborsRegressor_Ypred
#
# DecisionTreeRegressor
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_DecisionTreeRegressor_Ypred
#
# SVR
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_SVR_Ypred
#
# MLPRegressor
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_MLPRegressor_Ypred
#
# RandomForestRegressor
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_RandomForestRegressor_Ypred
#
# AdaBoostRegressor
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_AdaBoostRegressor_Ypred
#
# GradientBoostingRegressor
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_GradientBoostingRegressor_Ypred
#
# DummyRegressor
# y_true column: Seed0_Subset4_N43_Ytrue
# y_pred column: Seed0_Subset4_N43_DummyRegressor_Ypred
#
#
# N43, Seed0, Subset12:
#
# LinearRegression
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_LinearRegression_Ypred
#
# SGDRegressor
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_SGDRegressor_Ypred
#
# Lasso
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_Lasso_Ypred
#
# BayesianRidge
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_BayesianRidge_Ypred
#
# KNeighborsRegressor
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_KNeighborsRegressor_Ypred
#
# DecisionTreeRegressor
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_DecisionTreeRegressor_Ypred
#
# SVR
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_SVR_Ypred
#
# MLPRegressor
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_MLPRegressor_Ypred
#
# RandomForestRegressor
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_RandomForestRegressor_Ypred
#
# AdaBoostRegressor
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_AdaBoostRegressor_Ypred
#
# GradientBoostingRegressor
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_GradientBoostingRegressor_Ypred
#
# DummyRegressor
# y_true column: Seed0_Subset12_N43_Ytrue
# y_pred column: Seed0_Subset12_N43_DummyRegressor_Ypred
#
#
# N43, Seed1, Subset4:
#
# LinearRegression
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_LinearRegression_Ypred
#
# SGDRegressor
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_SGDRegressor_Ypred
#
# Lasso
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_Lasso_Ypred
#
# BayesianRidge
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_BayesianRidge_Ypred
#
# KNeighborsRegressor
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_KNeighborsRegressor_Ypred
#
# DecisionTreeRegressor
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_DecisionTreeRegressor_Ypred
#
# SVR
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_SVR_Ypred
#
# MLPRegressor
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_MLPRegressor_Ypred
#
# RandomForestRegressor
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_RandomForestRegressor_Ypred
#
# AdaBoostRegressor
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_AdaBoostRegressor_Ypred
#
# GradientBoostingRegressor
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_GradientBoostingRegressor_Ypred
#
# DummyRegressor
# y_true column: Seed1_Subset4_N43_Ytrue
# y_pred column: Seed1_Subset4_N43_DummyRegressor_Ypred
#
#
# N43, Seed1, Subset12:
#
# LinearRegression
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_LinearRegression_Ypred
#
# SGDRegressor
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_SGDRegressor_Ypred
#
# Lasso
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_Lasso_Ypred
#
# BayesianRidge
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_BayesianRidge_Ypred
#
# KNeighborsRegressor
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_KNeighborsRegressor_Ypred
#
# DecisionTreeRegressor
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_DecisionTreeRegressor_Ypred
#
# SVR
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_SVR_Ypred
#
# MLPRegressor
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_MLPRegressor_Ypred
#
# RandomForestRegressor
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_RandomForestRegressor_Ypred
#
# AdaBoostRegressor
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_AdaBoostRegressor_Ypred
#
# GradientBoostingRegressor
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_GradientBoostingRegressor_Ypred
#
# DummyRegressor
# y_true column: Seed1_Subset12_N43_Ytrue
# y_pred column: Seed1_Subset12_N43_DummyRegressor_Ypred
#
# performance_metrics dict:
# {'LinearRegression_MAE': [2555156671624.1978, 264865159207.09763, 106175741142.87738, 564052194566.3336], 'SGDRegressor_MAE': [0.12104124792660678, 0.16856754282415878, 0.12917152045535568, 0.17162813419629303], 'Lasso_MAE': [0.12024088411189357, 0.1697196076972291, 0.12523812747030677, 0.17033625136632669], 'BayesianRidge_MAE': [0.11691217592148849, 0.16555011534039538, 0.12240228043514696, 0.1623441131613552], 'KNeighborsRegressor_MAE': [0.12059342693369154, 0.16832803634723928, 0.12718616475243222, 0.16652879597290712], 'DecisionTreeRegressor_MAE': [0.1194374723323284, 0.1697196076972291, 0.12523812747030677, 0.17033625136632669], 'SVR_MAE': [0.12139613549002432, 0.16139460732185815, 0.1266205854913228, 0.16392818895087363], 'MLPRegressor_MAE': [1.3665567928920324, 11.655500775733566, 0.16475047286823533, 0.1902976342942672], 'RandomForestRegressor_MAE': [0.1202378018796877, 0.1721983266954844, 0.12494974395452114, 0.17022510900158414], 'AdaBoostRegressor_MAE': [0.11860800948342817, 0.16589130069337388, 0.12306174937969361, 0.16295426218362016], 'GradientBoostingRegressor_MAE': [0.11966600212238042, 0.18822300278341098, 0.12164739528213021, 0.17144157903210958], 'DummyRegressor_MAE': [0.12024088411189357, 0.1697196076972291, 0.12523812747030677, 0.17033625136632669], 'LinearRegression_MSE': [1.1823299493211555e+25, 4.2747601697425174e+23, 2.870507716397515e+22, 8.101150545271076e+23], 'SGDRegressor_MSE': [0.021885761653258295, 0.038802625345445416, 0.024707084690450163, 0.04381135111066915], 'Lasso_MSE': [0.020840853223256326, 0.039425796413568394, 0.020608197440305235, 0.04028201152155268], 'BayesianRidge_MSE': [0.020198680169691587, 0.037339001628176015, 0.021566784197282085, 0.03801335509552607], 'KNeighborsRegressor_MSE': [0.020424844385272593, 0.03924679150534967, 0.021462380155129697, 0.04045605813904474], 'DecisionTreeRegressor_MSE': [0.022917126298453074, 0.039425796413568394, 0.020608197440305235, 0.04028201152155268], 'SVR_MSE': [0.020123357391623846, 0.03524124572022647, 0.02124725914219713, 0.037556543709423275], 'MLPRegressor_MSE': [1.887908487682278, 153.44705471552976, 0.041581794948208795, 0.057266681346450896], 'RandomForestRegressor_MSE': [0.020842385459599436, 0.04222594108229737, 0.02056996220323992, 0.040147833775799655], 'AdaBoostRegressor_MSE': [0.022446644143853594, 0.03943351807405358, 0.02316398452667473, 0.03799082290917768], 'GradientBoostingRegressor_MSE': [0.02126677486320724, 0.05570799528883128, 0.020469261291459463, 0.04148053250398866], 'DummyRegressor_MSE': [0.020840853223256326, 0.039425796413568394, 0.020608197440305235, 0.04028201152155268], 'LinearRegression_R2': [-5.7920767109499304e+26, -1.1030030642360774e+25, -1.406263321200731e+24, -2.0903772336667554e+25], 'SGDRegressor_R2': [-0.07215427001592079, -0.0012120670388093835, -0.21040144833976293, -0.13048449632112158], 'Lasso_R2': [-0.02096559983155677, -0.017291556188824497, -0.009596734780236593, -0.0394153193475566], 'BayesianRidge_R2': [0.010493601469125147, 0.0365533602818533, -0.056557953132823746, 0.01912386860453119], 'KNeighborsRegressor_R2': [-0.0005858817721571263, -0.012672748245490473, -0.0514431933213344, -0.04390632448033327], 'DecisionTreeRegressor_R2': [-0.12267944824861043, -0.017291556188824497, -0.009596734780236593, -0.0394153193475566], 'SVR_R2': [0.014183563893748863, 0.09068110318694922, -0.040904402974995424, 0.03091118345879551], 'MLPRegressor_R2': [-91.48611853389653, -3958.346602582035, -1.0370944391238877, -0.47767858732298096], 'RandomForestRegressor_R2': [-0.02104066204615851, -0.08954281771628514, -0.007723588397273717, -0.035953069097799384], 'AdaBoostRegressor_R2': [-0.09963115507006215, -0.01749079579146784, -0.134804885792299, 0.019705276999600674], 'GradientBoostingRegressor_R2': [-0.04183093283666017, -0.4374160670101632, -0.0027902451479460133, -0.07034130895552071], 'DummyRegressor_R2': [-0.02096559983155677, -0.017291556188824497, -0.009596734780236593, -0.0394153193475566]}
